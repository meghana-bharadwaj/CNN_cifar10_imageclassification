# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to range [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert class labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Print dataset shapes
print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize pixel values to range [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert class labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Print dataset shapes
print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
# Out:
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)

# %%
# Display sample images
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[np.argmax(y_train[i])])
    plt.axis('off')
plt.show()

# %%
# Build the CNN model
model = models.Sequential([
    # Convolutional layer + Pooling
    layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)),
    layers.MaxPooling2D((2, 2)),
    
    # Another Convolutional layer + Pooling
    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.MaxPooling2D((2, 2)),
    
    # Fully connected layers
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')  # Output layer for 10 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# c:\MachineLearningProjects\imgenv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 30, 30, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 13, 13, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2304)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 315,722 (1.20 MB)
#  Trainable params: 315,722 (1.20 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
history = model.fit(x_train, y_train, epochs=10, batch_size=64, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.3816 - loss: 1.6955 - val_accuracy: 0.5855 - val_loss: 1.2039
# Epoch 2/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.5981 - loss: 1.1456 - val_accuracy: 0.6286 - val_loss: 1.0553
# Epoch 3/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6531 - loss: 0.9855 - val_accuracy: 0.6341 - val_loss: 1.0439
# Epoch 4/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.6903 - loss: 0.8930 - val_accuracy: 0.6810 - val_loss: 0.9209
# Epoch 5/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7144 - loss: 0.8199 - val_accuracy: 0.6844 - val_loss: 0.9115
# Epoch 6/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7438 - loss: 0.7325 - val_accuracy: 0.6969 - val_loss: 0.8784
# Epoch 7/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7664 - loss: 0.6749 - val_accuracy: 0.7033 - val_loss: 0.8694
# Epoch 8/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.7809 - loss: 0.6276 - val_accuracy: 0.7118 - val_loss: 0.8877
# Epoch 9/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8041 - loss: 0.5609 - val_accuracy: 0.7059 - val_loss: 0.8920
# Epoch 10/10
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8220 - loss: 0.5126 - val_accuracy: 0.7025 - val_loss: 0.9341

# %%
# Evaluate model
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7041 - loss: 0.9322
# Test Accuracy: 70.25%

# %%
# Plot training accuracy and loss
plt.figure(figsize=(12, 4))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.title('Accuracy')

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss')

plt.show()

# %%
# Make predictions
predictions = model.predict(x_test[:5])

# Display predictions
plt.figure(figsize=(10, 5))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(x_test[i])
    plt.title(f"Predicted: {class_names[np.argmax(predictions[i])]}\nTrue: {class_names[np.argmax(y_test[i])]}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step

# %%
pip install tensorflow-gpu
# Out:
# Collecting tensorflow-gpu
#   Using cached tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
# Requirement already satisfied: python_version>"3.7" in c:\machinelearningprojects\imgenv\lib\site-packages (from tensorflow-gpu) (0.0.2)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py): started
#   Building wheel for tensorflow-gpu (setup.py): finished with status 'error'
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: tensorflow-gpu
#     Running setup.py install for tensorflow-gpu: started
#     Running setup.py install for tensorflow-gpu: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Command errored out with exit status 1:
#    command: 'c:\MachineLearningProjects\imgenv\Scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"'; __file__='"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\megha\AppData\Local\Temp\pip-wheel-2l8hwvr1'
#        cwd: C:\Users\megha\AppData\Local\Temp\pip-install-h400bhr5\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\
#   Complete output (17 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\megha\AppData\Local\Temp\pip-install-h400bhr5\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\setup.py", line 37, in <module>
#       raise Exception(TF_REMOVAL_WARNING)
#   Exception:
#
#   =========================================================
#   The "tensorflow-gpu" package has been removed!
#
#   Please install "tensorflow" instead.
#
#   Other than the name, the two packages have been identical
#   since TensorFlow 2.1, or roughly since Sep 2019. For more
#   information, see: pypi.org/project/tensorflow-gpu
#   =========================================================
#
#
#   ----------------------------------------
#   ERROR: Failed building wheel for tensorflow-gpu
#     ERROR: Command errored out with exit status 1:
#      command: 'c:\MachineLearningProjects\imgenv\Scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"'; __file__='"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\megha\AppData\Local\Temp\pip-record-wptfj9ft\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\MachineLearningProjects\imgenv\include\site\python3.10\tensorflow-gpu'
#          cwd: C:\Users\megha\AppData\Local\Temp\pip-install-h400bhr5\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\
#     Complete output (17 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "C:\Users\megha\AppData\Local\Temp\pip-install-h400bhr5\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\setup.py", line 37, in <module>
#         raise Exception(TF_REMOVAL_WARNING)
#     Exception:
#
#     =========================================================
#     The "tensorflow-gpu" package has been removed!
#
#     Please install "tensorflow" instead.
#
#     Other than the name, the two packages have been identical
#     since TensorFlow 2.1, or roughly since Sep 2019. For more
#     information, see: pypi.org/project/tensorflow-gpu
#     =========================================================
#
#
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'c:\MachineLearningProjects\imgenv\Scripts\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"'; __file__='"'"'C:\\Users\\megha\\AppData\\Local\\Temp\\pip-install-h400bhr5\\tensorflow-gpu_7cbb8f7d80ae49e1a9af0b312e3edca4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\megha\AppData\Local\Temp\pip-record-wptfj9ft\install-record.txt' --single-version-externally-managed --compile --install-headers 'c:\MachineLearningProjects\imgenv\include\site\python3.10\tensorflow-gpu' Check the logs for full command output.
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\MachineLearningProjects\imgenv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
print("GPU available:", tf.config.list_physical_devices('GPU'))
# Out:
# GPU available: []

# %%
history = model.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8606 - loss: 0.4125 - val_accuracy: 0.7165 - val_loss: 0.9087
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8818 - loss: 0.3581 - val_accuracy: 0.7041 - val_loss: 0.9756
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8846 - loss: 0.3472 - val_accuracy: 0.7152 - val_loss: 0.9807
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.8982 - loss: 0.3119 - val_accuracy: 0.7049 - val_loss: 1.0244
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9033 - loss: 0.2890 - val_accuracy: 0.7050 - val_loss: 1.0483
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9151 - loss: 0.2574 - val_accuracy: 0.7066 - val_loss: 1.1025
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9275 - loss: 0.2227 - val_accuracy: 0.7048 - val_loss: 1.2022
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9354 - loss: 0.1984 - val_accuracy: 0.6964 - val_loss: 1.2577
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9431 - loss: 0.1860 - val_accuracy: 0.7007 - val_loss: 1.2833
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9548 - loss: 0.1476 - val_accuracy: 0.7060 - val_loss: 1.3721
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9591 - loss: 0.1327 - val_accuracy: 0.6962 - val_loss: 1.4517
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9650 - loss: 0.1144 - val_accuracy: 0.7027 - val_loss: 1.5505
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9726 - loss: 0.0926 - val_accuracy: 0.6951 - val_loss: 1.6154
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9677 - loss: 0.1008 - val_accuracy: 0.6893 - val_loss: 1.7092
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9735 - loss: 0.0857 - val_accuracy: 0.6905 - val_loss: 1.7658
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9813 - loss: 0.0670 - val_accuracy: 0.6771 - val_loss: 1.8904
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9786 - loss: 0.0700 - val_accuracy: 0.6931 - val_loss: 1.8891
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0